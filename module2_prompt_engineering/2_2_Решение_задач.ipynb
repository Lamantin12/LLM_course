# %%
# !pip install openai langchain tiktoken langchain-openai langchain-community -q
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Если используете ключ от OpenAI, запустите эту ячейку 👇

# %%
import os
from getpass import getpass
from langchain_openai import ChatOpenAI


# os.environ['OPENAI_API_KEY'] = "Введите ваш OpenAI API ключ"
os.environ['OPENAI_API_KEY'] = getpass(prompt='Введите ваш OpenAI API ключ')

# Инициализируем языковую модель
llm = ChatOpenAI(temperature=0.0)

# %% [markdown]
# ## Если используете ключ из курса, запустите эти ячейки 👇

# %%
# !wget https://raw.githubusercontent.com/a-milenkin/LLM_practical_course/main/notebooks/utils.py

# %%
from utils import ChatOpenAI
from getpass import getpass

#course_api_key= "Введите ваш API ключ с курса"
course_api_key = getpass(prompt='Введите API ключ')

# Инициализируем языковую модель
llm = ChatOpenAI(course_api_key=course_api_key)

# %% [markdown]
# # Задание 2.2.
#
# Переделай его в шаблон так, чтобы можно было менять:
#
# - стиль ответа
# - вариант ответа, если модель не знает (вместо "Я не знаю")
# - контекст
# - вопрос
#  И чтобы он подходил под приведённый ниже шаблон.

# %%
template = '''
Ответь на вопрос, исходя из контекста ниже
в стиле {style}. Если на вопрос невозможно ответить, 
используя предоставленную информацию ответь «{no_answer}».

Context: {context}

Question: {query}

Answer:
'''

# %%
from langchain import PromptTemplate
prompt_template = PromptTemplate(
    input_variables=["style", "no_answer", "context", "query"],
    template=template
)

# %%
prompt_template
# Out:
# PromptTemplate(input_variables=['context', 'no_answer', 'query', 'style'], input_types={}, partial_variables={}, template='\nОтветь на вопрос, исходя из контекста ниже\nв стиле {style}. Если на вопрос невозможно ответить, \nиспользуя предоставленную информацию ответь «{no_answer}».\n\nContext: {context}\n\nQuestion: {query}\n\nAnswer:\n')

# %% [markdown]
# # Задание 2.2.7: ⚔️ Spam 🆚 Crypto

# %%
import pandas as pd
from langchain import PromptTemplate
from tqdm import tqdm

# %%
df = pd.read_csv('https://stepik.org/media/attachments/lesson/1110806/100_crypto_messages.csv')

# %%
df
# Out:
#     text_id                                               text
# 0       143              Удаленная работа. От нас: Зп от 2500$
# 1       179  Что вы думаете о концепции децентрализованных ...
# 2       147  Удалённый заработок. Время 1-2часа в день. Мож...
# 3       157  Меня всегда интересовал вопрос безопасности хр...
# 4       168  Я слышал, что некоторые банки начали экспериме...
# ..      ...                                                ...
# 95      209  Работа в сфере криптовалютной журналистики или...
# 96      200  Какие криптовалюты вы видите в будущем как осн...
# 97      229  Исследование и анализ рынка криптовалют также ...
# 98      101  Набираю людей в команду по межбиржевой торговл...
# 99      161  Я слышал о проекте, который предоставляет кред...
#
# [100 rows x 2 columns]

# %%
# Напишите промпт, указав инструкцию, запрос и выходной индикатор
template = """Очень внимательно прочитай контекст ниже и ответь на вопрос. 
Ответом будет число 1 или 0. Если не знаешь ответ на вопрос напиши 0.

Context: {text_input}

Question: Является ли это сообщение спамом?

Answer: 
"""

prompt_template = PromptTemplate(
    input_variables=["text_input"],
    template=template
)

# %%
spam_labels = [] # Список, где будем хранить ответы модели

for text_input in tqdm(df['text']):
    prompt = prompt_template.format(text_input=text_input) # Добавляем сообщение в промпт
    spam_label = llm.invoke(prompt).content # Сохраняем ответ модели
    spam_labels.append(spam_label) # Добавляем ответ в список
    # break # Для отладки. Уберите, когда убедитесь, что на одном примере работает
# Out:
# 100%|██████████| 100/100 [01:13<00:00,  1.37it/s]

# %%
df['text'].iloc[0], spam_label
# Out:
# ('Удаленная работа. От нас: Зп от 2500$', '0')

# %%
df['is_spam'] = [int(e) for e in spam_labels]  # Создаём новый столбец из ответов модели

# %%
df.to_csv('2_2_7_solution.csv', index=False) # Сохраняем файл, отправляем на Stepik, получаем баллы :)

# %% [markdown]
# # Задание 2.2.8: 💼 ChatGPT - ваш ручной карьерный консультант

# %% [markdown]
# В данной задаче очень удобно использовать `OutputParser` (подробнее о нем в [ноутбуке](https://github.com/a-milenkin/LLM_practical_course/blob/main/notebooks/M2.2_LangChain_Prompting.ipynb))

# %%
import pandas as pd
from langchain.output_parsers import ResponseSchema
from langchain.output_parsers import StructuredOutputParser
from langchain.prompts import ChatPromptTemplate

# %%
df = pd.read_csv('https://stepik.org/media/attachments/lesson/1110806/vacancies_messages_50.csv')

# %%
df.head(5)
# Out:
#    text_id                                               text
# 0        9  #вакансия #vacancy #Python #удаленка #flask #r...
# 1       31  #ВАКАНСИЯ  #Системный_аналитик #РФ\n \nАКЦИОНЕ...
# 2       28  #вакансия #vacancy #job #senior #data #DB #dat...
# 3       49  #вакансия #fulltime #remote \n\n🔎 Ищем Руковод...
# 4       18  #vacancy #job #analyst #travel #sirenatravel #...

# %%
df.text.iloc[0]
# Out:
# '#вакансия #vacancy #Python #удаленка #flask #relocation #senior\n\nПозиция: Senior Python developer\nКомпания: Collectly\nФормат работы: Удаленно (не на территории РФ/РБ)\nВилка: 6000-9000$.net\nТрудоустройство: ИП или ТК Армении\nЗанятость: fulltime\n\nКонтакты: @ann_gfio\n\nCollectly - американская технологическая компания, прошедшая акселератор Y Combinator, специализирующаяся на автоматизации биллинга в медицинской сфере США. За почти 4 года существования компания стала прибыльной и стабильной, а также приобрела статус быстрорастущей организации.\n\nCollectly - первая в мире система, обеспечивающая автономное взаимодействие американских медицинских учреждений с пациентами в отношении медицинских счетов. Компания помогает пациентам разобраться в страховых планах, оплатить счета и получить финансовую помощь, снижая операционные расходы медицинских учреждений. Работа компании Collectly решает важные социальные проблемы в США и получает признание ведущих отраслевых журналов.\n\n🔎 Кого ищем? \n\nМы ищем сильного инженера, который готов работать в маленькой, но быстрорастущей технической команде: нужно уметь решать практические задачи просто (=> быстро), при этом свобода выбора за решение лежит на вас. Но и ответственность тоже! \n\nПроцессы и инструменты:\n- Недельные спринты с одним большим совещанием. JIRA для задач, Slack и Zoom для общения;\n- Внедрен CI/CD на основе Gitlab, тесты в пайплайне. Релизы каждой фичи независимые. Кто фичу писал — тот за неё и ответственный;\n- Code review перед Merge Request, посмотреть может каждый.\n\nСтек:\nPython, Flask, SqlAlchemy, PostgreSQL, Marshmallow, Celery, RabbitMQ, Redis. Custom REST API framework.\n\nТребования:\n- У вас должен быть практический опыт коммерческой web разработки от 4 лет и более;\n- Есть большой опыт работы с SQLAlchemy;\n- Хорошо знаете английский язык - В2 и выше;\n- Опыт работы с асинхронным кодом.\n\nМы предлагаем:\n- Полностью удаленная full-time вакансия; \n- Опцион (право на получение акций) в американском стартапе.'

# %%
template = """Из следующего текста извлеки информацию. Если явной информации нет - пиши None:

job_title: Позиция, про которую написан текст. Нужно написать ее как в вакансии, 
без учета уровня, например если написано Senior Python developer нужно написать Python developer.

company: Название компании, которая нанимает человека. Только название, как в тексте.

salary: Зарплата.
Может быть написано в виде тысяч: 100к или 100 тыс. - надо умножить на 1000 и оставить только число.
Например на 100к или 100 тыс. надо написать 100000.
Не пиши net/gross/на руки и.т.д.
Если в тексте указан диапазон пиши два числа через тире без пробелов между тире и числами.
Если указана только нижняя граница, то пиши 'от' и число, если только верхняя - то 'до' и число.
После числа или диапазона надо написать 'руб.' или '$' через пробел в зависимости от валюты.
Если зарплата указана в час, то надо после всего через пробел добавить 'в час'.

tg: Контакт телеграм, с которым нужно связаться, чтобы откликнуться. 
Пишется вот так: @<контакт> . Если указано больше 1 контакта надо вывести все в списке.

grade: Уровень знаний кандидата. 
Вот возможные варианты в порядке возрастания: intern, junior, junior+, middle, middle+, senior, lead
Может быть написано на русском языке, например ведущий это то же самое что и lead
Если указано несколько, напиши через запятую в порядке возрастания.

text: {text}

{format_instructions}
"""

prompt = ChatPromptTemplate.from_template(template=template)

# %%
job_title_schema = ResponseSchema(
    name="job_title",
    description="""Позиция, про которую написан текст. Нужно написать ее как в вакансии, 
    без учета уровня, например если написано Senior Python developer нужно написать Python developer
    """
)


company_schema = ResponseSchema(
    name="company",
    description="""Название компании, которая нанимает человека. Только название, как в тексте.
    """
)


salary_schema = ResponseSchema(
    name="salary",
    description="""Зарплата.
    Может быть написано в виде тысяч: 100к или 100 тыс. - надо умножить на 1000 и оставить только число.
    Например на 100к или 100 тыс. надо написать 100000.
    Не пиши net/gross/на руки и.т.д.
    Если в тексте указан диапазон пиши два числа через тире без пробелов между тире и числами.
    Если указана только нижняя граница, то пиши 'от' и число, если только верхняя - то 'до' и число.
    После числа или диапазона надо написать 'руб.' или '$' через пробел в зависимости от валюты.
    Если зарплата указана в час, то надо после всего через пробел добавить 'в час'."""
)


tg_schema = ResponseSchema(
    name="tg",
    description="""Контакт телеграм, с которым нужно связаться, чтобы откликнуться. 
    Пишется вот так: @<контакт> . Если указано больше 1 контакта надо вывести все в списке. """
)


grade_schema = ResponseSchema(
    name="grade",
    description="""Уровень знаний кандидата. 
    Вот возможные варианты в порядке возрастания: intern, junior, junior+, middle, middle+, senior, lead
    Может быть написано на русском языке, например ведущий это то же самое что и lead
    Если указано несколько, напиши через запятую в порядке возрастания."""
)

response_schemas = [
    job_title_schema,
    company_schema,
    salary_schema,
    tg_schema,
    grade_schema
]

# %%
output_parser = StructuredOutputParser.from_response_schemas(response_schemas) # Создаём парсер и подаём в него список со схемами
format_instructions = output_parser.get_format_instructions() # Получаем инструкции по форматированию ответа

# %%
dict_list = [] # Список из словарей, где будем хранить полученную информацию
for text_input in tqdm(df['text']):
    messages = prompt.format_messages(
        text=text_input,
        format_instructions=format_instructions
    )
    response = llm.invoke(messages) # Ответ модели
    dict_list.append(output_parser.parse(response.content)) # Переводим содержимое ответа модели в словарь и добавляем в список
    # break # Для отладки. Уберите, когда убедитесь, что на одном примере работает
# Out:
# 100%|██████████| 50/50 [01:13<00:00,  1.47s/it]

# %%
result_df = pd.DataFrame(dict_list) # Создаем датафрейм из полученной информации
ans_df = pd.concat([df, result_df], axis=1) # Объединяем всё в один датафрейм
ans_df.to_csv('2_2_8_solution.csv', index=False) # Сохраняем файл, отправляем на Stepik, получаем баллы :)

# %%
ans_df
# Out:
#     text_id                                               text  \
# 0         9  #вакансия #vacancy #Python #удаленка #flask #r...
# 1        31  #ВАКАНСИЯ  #Системный_аналитик #РФ\n \nАКЦИОНЕ...
# 2        28  #вакансия #vacancy #job #senior #data #DB #dat...
# 3        49  #вакансия #fulltime #remote \n\n🔎 Ищем Руковод...
# 4        18  #vacancy #job #analyst #travel #sirenatravel #...
# 5        48  #вакансия #fulltime #remote #lookfor #devops\n...
# 6        41  #вакансия #senior #middle+ #lead #удаленка #оф...
# 7         6  #job #python #django #javascript #react #fulls...
# 8        17  #вакансия #vacancy #middle #senior #remote #уд...
# 9         4  Вакансия: Разработчик (Vue.js / Golang) для на...
# 10       50  #vacancy #relocate #fulltime #LeadUIUXDesigner...
# 11       32  #вакансия #удаленка #vacancy #startup #QA #mid...
# 12       38  ✅Senior Full Stack PHP-разработчик\nот 250 000...
# 13        5  #job #вакансия #работа #fulltime  #TS #Typescr...
# 14       33  🏳️ Вакансия: React Developer 🏳️\n\nТолько для ...
# 15       15  #вакансия #PHP #Symfony #developer #fulltime #...
# 16       29  📝 Retention Manager (iGaming)\nФормат: удаленн...
# 17       19  #job #вакансия #работа #fulltime #remote #pyth...
# 18       24  #Вакансия #Удаленно\nВсем привет!🖐\nМы - «КСА»...
# 19       40  #вакансия #удаленно #системный_аналитик\n\nКом...
# 20       12  #вакансия #qa #auto #fulltime #remote #vacancy...
# 21       39  Привет! \nМы компания Траст Строй, занимаемся ...
# 22       45  #вакансия #продажи \n\nПозиция: «Менеджер по р...
# 23        1  #вакансия #node #vue #fullstack #удаленно \n\n...
# 24       26  #вакансия #удалено #C #NET \n\n\n🔥C# Engineer🔥...
# 25       13  #вакансия #vacancy #systemanalyst #analyst #sa...
# 26       30  #вакансия #удалёнка #IT\nЗдравствуйте! Компани...
# 27       20  #job #analyst #vacancy #Russia #fulltime #вака...
# 28       22  #vacancy #Java_developer\n\nПозиция: Java deve...
# 29       47  #вакансия  #vacancy #1C-bitrix  #php #office #...
# 30       43  #junior #vacancy #вакансия #recruiter\n\nJunio...
# 31        3  #job #vacancy #C #developer #backend #middle #...
# 32       23  #job #вакансия #работа #fulltime #remote #php ...
# 33       44  #вакансия #python #middle #fulltime #remote #у...
# 34       35  #vacancy #вакансия #go #developer #wildberries...
# 35       27  #SDR #remote #tashkent\nPtolemay (https://www....
# 36       21  #job #vacancy #sirenatravel #developer #backen...
# 37       37  ✅Системный администратор (Anykey)\nВ компанию\...
# 38       16  #вакансия #стажировка #удаленка #аналитик #ful...
# 39        2  #copywriter #вакансия  #fulltime #удаленка  #r...
# 40       42  #вакансия #работа #ПолнаяЗанятость #удаленнаяр...
# 41        7  #аналитик #AWG  #Москва #CA #Senior #системный...
# 42       34  #vacancy #вакансия #ios #remote \n\n⭐️ Release...
# 43       25  #job #vacancy #вакансия #офис #релокация #Open...
# 44       46  #vacancy #вакансия #go #developer #wildberries...
# 45       36  #вакансия\n\nMiddle+/Senior Backend Engineer в...
# 46       10  #вакансия\n\nВсем привет! \n\nИщем программист...
# 47       11  #вакансия #vacancy #DWH #remote #удалённо    \...
# 48       14  #job #вакансия #работа #fulltime  #JavaScript ...
# 49        8  #вакансия #HR #junior #remote #crypto #blockch...
#
#                                            job_title             company  \
# 0                                   Python developer           Collectly
# 1                                 Системный аналитик          АО «ГНИВЦ»
# 2                             Database Administrator       Match Systems
# 3   Руководитель отдела системного администрирования     финтех компания
# 4                                            Analyst       Sirena Travel
# 5                                     DevOps инженер            Mad Devs
# 6                                 Системный аналитик           Платформа
# 7              Python/Django full-stack разработчика              ivelum
# 8                                     Go разработчик      КА Алешин Д.А.
# 9                                        Разработчик                None
# 10                                    UI/UX Designer                None
# 11                            QA automation Engineer                CFPS
# 12                        Full Stack PHP-разработчик           GetCourse
# 13                              Frontend разработчик           Travelata
# 14                                   React Developer        крупный банк
# 15                                     PHP-developer             KT.Team
# 16                                 Retention Manager                None
# 17                                  Python developer            Skillbox
# 18                                Программист 1С:ЗУП                 КСА
# 19                                Системный аналитик               Amber
# 20                                      Tech Lead QA           RecruitIT
# 21                        Backend Python разработчик         Траст Строй
# 22             Менеджер по развитию партнерской сети               AMBER
# 23                            Full-stack разработчик         КА "АйтиКА"
# 24                                       C# Engineer                GGEM
# 25                                    System Analyst               Brief
# 26                          Разработчик PowerBuilder       Outlines Tech
# 27                                Системный аналитик             INFOPRO
# 28                                    Java developer                None
# 29                                   PHP программист               100UP
# 30                                      IT Recruiter            AIPeople
# 31                                   C/C++ Developer                 NTS
# 32                                     PHP developer            Водоходъ
# 33                                  Python Developer  ALEX GROUP COMPANY
# 34                                      Go Developer         WILDBERRIES
# 35                                               SDR            Ptolemay
# 36                                      C# Developer       Sirena Travel
# 37                           Системный администратор         MANUFAQTURY
# 38                                          Аналитик           Автомакон
# 39                                        Копирайтер  ALEX GROUP COMPANY
# 40                                                QA           Dreamsoft
# 41                                Системный аналитик                 AWG
# 42                                   Release manager         WILDBERRIES
# 43                       DevOps (Openstack Engineer)           Mayflower
# 44                                      Go Developer         WILDBERRIES
# 45                                  Backend Engineer                Qlan
# 46                                       Программист                None
# 47                                     DWH developer          König Labs
# 48                              Frontend разработчик        Nobilis.Team
# 49                                        HR Manager  ALEX GROUP COMPANY
#
#                       salary                                     tg  \
# 0                6000-9000 $                              @ann_gfio
# 1         320000-370000 руб.                           @NatalyaMaki
# 2                  от 3000 $                            @lex_kertis
# 3                  от 3000 $                         @ResearcherRIT
# 4         120000-180000 руб.                              @ann_gfio
# 5                  до 5000 $                     @recruiter_maddevs
# 6         180000-300000 руб.                 @Alexandrabogdanova_96
# 7                4000-6000 $                            @lebedevaoi
# 8             до 500000 руб.                       @AleshinDmitry80
# 9                       None                                   None
# 10                      None                              @alesyaly
# 11        180000-250000 руб.                       @Ana_Itrecruiter
# 12            от 250000 руб.                              @Ritttka1
# 13        280000-320000 руб.                              @ann_gfio
# 14        180000-230000 руб.                                   None
# 15            до 240000 руб.                             @innahotim
# 16                      None                              @alesyaly
# 17        300000-400000 руб.                              @ann_gfio
# 18        220000-250000 руб.                              @saras770
# 19            до 300000 руб.                            @Sholpan771
# 20                 от 3000 $                         @ResearcherRIT
# 21                      None                         @Lyubov_Vladim
# 22            от 130000 руб.                            @Sholpan771
# 23        300000-380000 руб.                              @artur_vv
# 24       от 17 до 20 $ в час                             @AlexMayel
# 25        240000-300000 руб.                             @smirnsvet
# 26            до 290000 руб.                                @mnoita
# 27        100000-200000 руб.                              @ann_gfio
# 28        200000-250000 руб.                            @Sholpan771
# 29        150000-200000 руб.                       @romanenko_daria
# 30                      None                        @nastyaishiring
# 31        140000-300000 руб.                              @ann_gfio
# 32        180000-200000 руб.                              @ann_gfio
# 33         от 3000 до 3600 $                           @danilavaren
# 34  от 150000 до 600000 руб.                             @hr_legoit
# 35                 300-1000$  @Dmitriy_Ptolemay, @rinapina_ptolemay
# 36        300000-400000 руб.                              @ann_gfio
# 37             от 80000 руб.                                   None
# 38                      None                            @nikolaazzp
# 39         80000-140000 руб.                           @danilavaren
# 40                      None                              @DreamITB
# 41            до 350000 руб.                                @ElivHR
# 42  от 150000 до 350000 руб.                             @invader_s
# 43               5000-6000 $                        @Alexandr_Mayel
# 44        150000-600000 руб.                          @Fl_recruiter
# 45        110000-140000 руб.                              @laptev13
# 46                      None                             @vlrstrtsv
# 47        250000-300000 руб.                    @HrKristinaorekhova
# 48        180000-250000 руб.                           @Anna_HRinIT
# 49          70000-90000 руб.                           @danilavaren
#
#                     grade
# 0                  middle
# 1                    None
# 2                  senior
# 3          middle, senior
# 4                  middle
# 5                  senior
# 6   middle+, senior, lead
# 7                  middle
# 8          middle, senior
# 9                  junior
# 10                 senior
# 11          middle,senior
# 12                 senior
# 13                 senior
# 14                middle+
# 15                middle+
# 16                   None
# 17                 senior
# 18                   None
# 19          middle,senior
# 20        middle+, senior
# 21                 senior
# 22                   None
# 23                 middle
# 24                   None
# 25        middle+, senior
# 26                   None
# 27                 middle
# 28                 middle
# 29                 middle
# 30                 junior
# 31         middle, senior
# 32         middle, senior
# 33                 middle
# 34                 middle
# 35                 junior
# 36                   None
# 37                   None
# 38                 intern
# 39                 middle
# 40                 middle
# 41                 senior
# 42                 middle
# 43                 senior
# 44                 middle
# 45        middle+, senior
# 46                   None
# 47                 middle
# 48                 middle
# 49                 junior
